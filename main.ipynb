# %%
import requests
url= "https://ekantipur.com/entertainment/2026/05/14/fashion-statement-at-cannes-the-controversial-dress-code-rule-08-34.html"
response = requests.get(url)
with open("file.html","w") as f:
   f.write(response.text)
